# %% [markdown]
# # trace

# %%
open sm'_operators

# %%
//// test

open testing

# %% [markdown]
# ## trace

# %% [markdown]
# ### trace_level

# %%
union trace_level =
    | Verbose
    | Debug
    | Info
    | Warning
    | Critical

# %% [markdown]
# ### read_state

# %%
inl read_state () =
    run_target function
        | Rust (Wasm) => fun () =>
            {
                trace_level = None
                repl_start = None
            }
        | Rust (Contract) => fun () =>
            {
                trace_level = None
                repl_start =
                    open rust.rust_operators
                    inl automation = env.get_environment_variable_comptime "AUTOMATION"
                    if automation <>. "True"
                    then None
                    else
                        inl timestamp : u64 = !\($'$"near_sdk::env::block_timestamp()"')
                        timestamp |> i64 |> Some
            }
        | _ => fun () =>
            join
                {
                    trace_level =
                        "TRACE_LEVEL"
                        |> env.get_environment_variable
                        |> reflection.union_try_pick
                    repl_start =
                        inl automation = env.get_environment_variable "AUTOMATION"
                        if automation <>. "True"
                        then None
                        else
                            date_time.now ()
                            |> date_time.ticks
                            |> fun (date_time.timestamp x) => x |> convert
                            |> fun (x : i64) =>
                                backend_switch {
                                    Gleam = fun () =>
                                        backend_switch {
                                            Gleam = fun () =>
                                                global "import gleam/float"
                                                global "import gleam/time/timestamp"
                                        }
                                        $'!x |> timestamp.to_unix_seconds |> float.round' : i64
                                    Fsharp = fun () => x
                                    Python = fun () => x
                                }
                            |> Some
                }

# %% [markdown]
# ### trace_state

# %%
type trace_state =
    {
        count : mut i64
        trace_file : mut (string -> ())
        enabled : mut bool
        acc : mut string
        level : mut trace_level
        repl_start : optionm'.option' i64
    }

# %% [markdown]
# ### new_trace_state

# %%
let new_trace_state trace_level' =
    inl { repl_start trace_level } = read_state ()
    {
        count = mut 1i64
        trace_file = mut ignore
        enabled = mut true
        acc = mut ""
        level = trace_level |> optionm'.default_value trace_level' |> mut
        repl_start = repl_start |> optionm'.box
    } : trace_state

# %% [markdown]
# ### init_trace_state

# %%
inl init_trace_state trace_level : () =
    inl trace_level = trace_level |> optionm'.default_value Verbose
    backend_switch {
        Gleam = fun () =>
            global "fn trace_state () { option.None }"
            $'let trace_state = fn () { case trace_state () { option.None -> !new_trace_state(!trace_level) |> option.Some' : ()
            $'  x -> x' : ()
            $'}}' : ()
        Fsharp = fun () =>
            backend_switch {
                Fsharp = fun () =>
                    global "module TraceState = let mutable trace_state = None"
            }
            fun () =>
                if $'TraceState.trace_state.IsNone' then
                    inl trace_state = new_trace_state trace_level |> optionm'.some'
                    $'TraceState.trace_state <- !trace_state ' : ()
            |> exec_unit
        Python = fun () =>
            global "class TraceState: trace_state = None"
            $'if TraceState.trace_state is None: TraceState.trace_state = !new_trace_state(!trace_level)' : ()
    }

# %% [markdown]
# ### get_trace_state_or_init

# %%
inl get_trace_state_or_init trace_level : trace_state =
    init_trace_state trace_level
    backend_switch {
        Gleam = fun () =>
            inl trace_level = trace_level |> optionm'.default_value Verbose
            $'trace_state () |> option.lazy_unwrap(fn () { !new_trace_state(!trace_level) })' : trace_state
        Fsharp = fun () =>
            $'TraceState.trace_state.Value' : trace_state
        Python = fun () =>
            $'TraceState.trace_state' : trace_state
    }

# %% [markdown]
# ### set_trace_level

# %%
inl set_trace_level new_level =
    inl ({ level } & trace_state) = get_trace_state_or_init None
    level <- new_level
    backend_switch {
        Gleam = fun () =>
            $'let trace_state = fn () { !(trace_state |> optionm'.some') }' : ()
    }

# %% [markdown]
# ### test_trace_level

# %%
inl test_trace_level level : bool =
    inl state = get_trace_state_or_init None
    inl level' = *state.level
    if *state.enabled |> not
    then false
    else
        inl level : i32 = real real_core.union_tag level
        inl level' : i32 = real real_core.union_tag level'
        level >= level'

# %%
//// test
///! gleam
///! fsharp
///! cuda
///! rust
///! typescript
///! python

test_trace_level Critical |> _assert_eq true
test_trace_level Verbose |> _assert_eq true
Debug |> set_trace_level
test_trace_level Verbose |> _assert_eq false
Verbose |> set_trace_level
test_trace_level Verbose |> _assert_eq true
# Out:
# .py output (Python):
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = false; expected = false }
# { name = __assert_eq; actual = true; expected = true }
#
#
# .rs output:
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = false; expected = false }
# { name = __assert_eq; actual = true; expected = true }
#
#
# .ts output:
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = false; expected = false }
# { name = __assert_eq; actual = true; expected = true }
#
#
# .py output:
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = false; expected = false }
# { name = __assert_eq; actual = true; expected = true }
#
#
# .gleam output (Gleam):
# warning: Unused imported module
#   ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:8:1
#   │
# 8 │ import gleam/time/calendar
#   │ ^^^^^^^^^^^^^^^^^^^^^^^^^^ This imported module is never used
#
# Hint: You can safely remove it.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:266:90
#     │
# 266 │ pub fn closure1 () -> fn(_) -> fn(       Nil) -> Nil   { fn(x : #(   String)) { let #(   v0 ) = x
#     │                                                                                          ^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v0`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:407:11
#     │
# 407 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │           ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v32`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:407:16
#     │
# 407 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │                ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v33`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:407:26
#     │
# 407 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │                          ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v35`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:407:36
#     │
# 407 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │                                    ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v37`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:449:11
#     │
# 449 │     let #(v104, v105, v106, v107, v108, v109) = trace_state () |> option.lazy_unwrap(fn () { v0(v103) })
#     │           ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v104`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:449:17
#     │
# 449 │     let #(v104, v105, v106, v107, v108, v109) = trace_state () |> option.lazy_unwrap(fn () { v0(v103) })
#     │                 ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v105`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:449:29
#     │
# 449 │     let #(v104, v105, v106, v107, v108, v109) = trace_state () |> option.lazy_unwrap(fn () { v0(v103) })
#     │                             ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v107`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:449:41
#     │
# 449 │     let #(v104, v105, v106, v107, v108, v109) = trace_state () |> option.lazy_unwrap(fn () { v0(v103) })
#     │                                         ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v109`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:490:35
#     │
# 490 │     let #(v175, v176, v177, v178, v179, v180) = trace_state () |> option.lazy_unwrap(fn () { v0(v174) })
#     │                                   ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v179`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:500:11
#     │
# 500 │     let #(v235, v236, v237, v238, v239, v240) = trace_state () |> option.lazy_unwrap(fn () { v0(v234) })
#     │           ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v235`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:500:17
#     │
# 500 │     let #(v235, v236, v237, v238, v239, v240) = trace_state () |> option.lazy_unwrap(fn () { v0(v234) })
#     │                 ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v236`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:500:29
#     │
# 500 │     let #(v235, v236, v237, v238, v239, v240) = trace_state () |> option.lazy_unwrap(fn () { v0(v234) })
#     │                             ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v238`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:500:41
#     │
# 500 │     let #(v235, v236, v237, v238, v239, v240) = trace_state () |> option.lazy_unwrap(fn () { v0(v234) })
#     │                                         ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v240`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:542:35
#     │
# 542 │     let #(v307, v308, v309, v310, v311, v312) = trace_state () |> option.lazy_unwrap(fn () { v0(v306) })
#     │                                   ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v311`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:552:11
#     │
# 552 │     let #(v367, v368, v369, v370, v371, v372) = trace_state () |> option.lazy_unwrap(fn () { v0(v366) })
#     │           ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v367`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:552:17
#     │
# 552 │     let #(v367, v368, v369, v370, v371, v372) = trace_state () |> option.lazy_unwrap(fn () { v0(v366) })
#     │                 ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v368`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:552:29
#     │
# 552 │     let #(v367, v368, v369, v370, v371, v372) = trace_state () |> option.lazy_unwrap(fn () { v0(v366) })
#     │                             ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v370`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\86ebd9fea15a7f85ad972cf66364fbc6575c71a3cccaeaf8b6ac42a7af8127a8\src\main.gleam:552:41
#     │
# 552 │     let #(v367, v368, v369, v370, v371, v372) = trace_state () |> option.lazy_unwrap(fn () { v0(v366) })
#     │                                         ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v372`.
#
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = false; expected = false }
# { name = __assert_eq; actual = true; expected = true }
# .fsx output:
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = true; expected = true }
# { name = __assert_eq; actual = false; expected = false }
# { name = __assert_eq; actual = true; expected = true }

# %% [markdown]
# ### trace_raw

# %%
inl trace_raw level fn =
    fun () =>
        inl trace_state =
            if level |> test_trace_level |> not
            then None
            else
                inl text = fn ()
                inl ({ count acc } & trace_state) = get_trace_state_or_init None
                fun () =>
                    count <- *count + 1
                |> exec_unit
                open rust
                open rust.rust_operators
                run_target_args (fun () => text, console.write_line) function
                    | Rust (Contract) => fun text, _ =>
                        inl new_acc =
                            if *acc = ""
                            then text
                            elif text = ""
                            then *acc
                            else *acc ++\# text

                        inl chunks =
                            new_acc
                            |> sm'.as_str
                            |> sm'.chars
                            |> rust.from_mut
                            |> iter_collect
                            |> am'.vec_chunks 15000
                            |> am'.vec_map sm'.from_iter

                        inl chunks_len = chunks |> am'.vec_len |> i32

                        if text <>. "" && chunks_len <= 1
                        then acc <- new_acc
                        else
                            acc <- ""
                            chunks
                            |> am'.vec_for_each''' near.log
                    | Rust _ => fun text, _ =>
                        !\\(text, $'\@"println\!(""{}"", $0)"')
                    | _ => fun text, write_line =>
                        text |> write_line

                text |> *trace_state.trace_file
                trace_state |> Some
        backend_switch {
            Gleam = fun () =>
                $'let trace_state = fn () { !(trace_state |> optionm'.box) }' : ()
        }
    |> exec_unit

# %% [markdown]
# ### trace

# %%
inl trace (level : trace_level) (text_fn : () -> string) (locals : () -> _) =
    fun () =>
        inl trace_state = get_trace_state_or_init None
        inl time =
            join
                run_target fun target =>
                    match target with
                    | Rust (Contract) => fun () =>
                        open rust.rust_operators
                        open rust
                        inl timestamp = near.block_timestamp ()
                        inl timestamp =
                            match trace_state.repl_start |> optionm'.unbox with
                            | Some repl_start => timestamp - u64 repl_start
                            | None => timestamp
                        inl timestamp_s = timestamp / 1_000_000_000
                        inl s = timestamp_s % 60
                        inl m = (timestamp_s / 60) % 60
                        inl h = (timestamp_s / 3600) % 24
                        inl str : sm'.std_string =
                            !\\((h, m, s), $'$"format\!(\\\"{{:02}}:{{:02}}:{{:02}}\\\", $0, $1, $2)"')
                        str |> sm'.from_std_string
                    | _ => fun () =>
                        match trace_state.repl_start |> optionm'.unbox with
                        | Some repl_start =>
                            inl t =
                                date_time.now ()
                                |> date_time.ticks
                                |> fun (date_time.timestamp x) => x |> convert
                                |> fun (x : i64) =>
                                    backend_switch {
                                        Gleam = fun () =>
                                            backend_switch {
                                                Gleam = fun () =>
                                                    global "import gleam/float"
                                                    global "import gleam/time/timestamp"
                                            }
                                            $'!x |> timestamp.to_unix_seconds |> float.round' : i64
                                        Fsharp = fun () => x
                                        Python = fun () => x
                                    }
                                |> flip (-) repl_start
                                |> date_time.time_span
                            date_time.date_time_milliseconds
                                1i32 1i32 1i32
                                (t |> date_time.hours)
                                (t |> date_time.minutes)
                                (t |> date_time.seconds)
                                (t |> date_time.milliseconds)
                        | None => date_time.now ()
                        |> date_time.format (
                            backend_switch {
                                Gleam = fun () => "%H:%M:%S"
                                Fsharp = fun () =>
                                    match target with
                                    | Rust _ => join "hh:mm:ss"
                                    | _ => join "HH:mm:ss"
                                Python = fun () => "%H:%M:%S"
                            }
                        )
        inl level_str =
            join
                inl level_str =
                    level
                    |> reflection.union_to_string
                    |> sm'.to_lower
                    |> sm'.index 0i32
                    |> sm'.format
                run_target function
                | Rust _ => fun () =>
                    open rust
                    open rust.rust_operators
                    inl color : rust.ref sm'.str =
                        match level with
                        | Verbose => !\($'"inline_colorization::color_bright_black"')
                        | Debug => !\($'"inline_colorization::color_bright_blue"')
                        | Info => !\($'"inline_colorization::color_bright_green"')
                        | Warning => !\($'"inline_colorization::color_yellow"')
                        | Critical => !\($'"inline_colorization::color_bright_red"')
                    inl level_str = level_str |> sm'.as_str
                    inl color_reset : rust.ref sm'.str = !\($'"inline_colorization::color_reset"')
                    !\\((color, level_str, color_reset), $'$"format\!(\\\"{{}}{{}}{{}}\\\", $0, $1, $2)"')
                    |> sm'.from_std_string
                | _ => fun () =>
                    inl color =
                        backend_switch {
                            Gleam = fun () =>
                                match level with
                                | Verbose => $'"\\u{001b}[90m"'
                                | Debug => $'"\\u{001b}[94m"'
                                | Info => $'"\\u{001b}[92m"'
                                | Warning => $'"\\u{001b}[93m"'
                                | Critical => $'"\\u{001b}[91m"'
                                : string
                            Fsharp = fun () =>
                                match level with
                                | Verbose => $'"\\u001b[90m"'
                                | Debug => $'"\\u001b[94m"'
                                | Info => $'"\\u001b[92m"'
                                | Warning => $'"\\u001b[93m"'
                                | Critical => $'"\\u001b[91m"'
                                : string
                            Python = fun () =>
                                match level with
                                | Verbose => $'"\\u001b[90m"'
                                | Debug => $'"\\u001b[94m"'
                                | Info => $'"\\u001b[92m"'
                                | Warning => $'"\\u001b[93m"'
                                | Critical => $'"\\u001b[91m"'
                                : string
                        }
                    inl color_reset =
                        backend_switch {
                            Gleam = fun () => $'"\\u{001b}[0m"' : string
                            Fsharp = fun () => join $'"\\u001b[0m"' : string
                            Python = fun () => $'"\\u001b[0m"' : string
                        }
                    color ++# level_str ++# color_reset
        inl text = text_fn ()
        if text = ""
        then ""
        else
            inl locals = locals ()
            join
                inl locals = locals |> sm'.format
                inl count = *trace_state.count
                time ++# " " ++# level_str ++# " #" ++# $count ++# " " ++# text ++# " / " ++# locals
                |> fun x =>
                    join
                        x
                        |> sm'.trim_start []
                        |> sm'.trim_end [ ' '; '/' ]
    |> trace_raw level

# %%
//// test
///! gleam
///! fsharp
///! cuda
///! rust
///! typescript
///! python

trace Debug (fun () => "test1") id
trace Debug (fun () => "test2") id
get_trace_state_or_init None .count
|> fun x => *x
|> _assert_eq 3
# Out:
# .py output (Python):
# 00:00:00 d #1 test1
# 00:00:00 d #2 test2
# { name = __assert_eq; actual = 3; expected = 3 }
#
#
# .rs output:
# 00:00:00 d #1 test1
# 00:00:00 d #2 test2
# { name = __assert_eq; actual = 3; expected = 3 }
#
#
# .ts output:
# 00:00:00 d #1 test1
# 00:00:00 d #2 test2
# { name = __assert_eq; actual = 3; expected = 3 }
#
#
# .py output:
# 00:00:00 d #1 test1
# 00:00:00 d #2 test2
# { name = __assert_eq; actual = 3; expected = 3 }
#
#
# .gleam output (Gleam):
# warning: Unused imported module
#    ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:10:1
#    │
# 10 │ import gleam/list
#    │ ^^^^^^^^^^^^^^^^^ This imported module is never used
#
# Hint: You can safely remove it.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:271:90
#     │
# 271 │ pub fn closure1 () -> fn(_) -> fn(       Nil) -> Nil   { fn(x : #(   String)) { let #(   v0 ) = x
#     │                                                                                          ^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v0`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:315:17
#     │
# 315 │ pub fn method4 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int)) -> String {
#     │                 ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v0`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:315:31
#     │
# 315 │ pub fn method4 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int)) -> String {
#     │                               ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:315:45
#     │
# 315 │ pub fn method4 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int)) -> String {
#     │                                             ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v2`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:315:59
#     │
# 315 │ pub fn method4 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int)) -> String {
#     │                                                           ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v3`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:315:73
#     │
# 315 │ pub fn method4 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int)) -> String {
#     │                                                                         ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v4`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:320:9
#     │
# 320 │     let v170 =
#     │         ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v170`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:341:21
#     │
# 341 │                 let v108 = v107
#     │                     ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v108`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:355:9
#     │
# 355 │     let v173 = "%H:%M:%S"
#     │         ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v173`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:396:9
#     │
# 396 │     let v1 = []
#     │         ^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:400:9
#     │
# 400 │     let v51 = [ " ", ..v47 ]
#     │         ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v51`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:404:31
#     │
# 404 │ pub fn method8 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                               ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:404:45
#     │
# 404 │ pub fn method8 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                             ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v2`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:404:59
#     │
# 404 │ pub fn method8 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                                           ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v3`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:404:73
#     │
# 404 │ pub fn method8 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                                                         ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v4`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:404:87
#     │
# 404 │ pub fn method8 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                                                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v5`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:427:32
#     │
# 427 │ pub fn method11 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:427:46
#     │
# 427 │ pub fn method11 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                              ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v2`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:427:60
#     │
# 427 │ pub fn method11 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                                            ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v3`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:427:74
#     │
# 427 │ pub fn method11 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                                                          ^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v4`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:427:88
#     │
# 427 │ pub fn method11 (v0 :    Mut0, v1 :    Mut1, v2 :    Mut2, v3 :    Mut3, v4 :    Mut4, v5 :    option.Option(Int), v6 :    String, v7 :    String) -> String {
#     │                                                                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v5`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:520:11
#     │
# 520 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │           ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v32`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:520:16
#     │
# 520 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │                ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v33`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:520:26
#     │
# 520 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │                          ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v35`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:520:36
#     │
# 520 │     let #(v32, v33, v34, v35, v36, v37) = trace_state () |> option.lazy_unwrap(fn () { v0(v31) })
#     │                                    ^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v37`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:584:11
#     │
# 584 │     let #(v653, v654, v655, v656, v657, v658) = trace_state () |> option.lazy_unwrap(fn () { v0(v652) })
#     │           ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v653`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:584:17
#     │
# 584 │     let #(v653, v654, v655, v656, v657, v658) = trace_state () |> option.lazy_unwrap(fn () { v0(v652) })
#     │                 ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v654`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:584:29
#     │
# 584 │     let #(v653, v654, v655, v656, v657, v658) = trace_state () |> option.lazy_unwrap(fn () { v0(v652) })
#     │                             ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v656`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:584:41
#     │
# 584 │     let #(v653, v654, v655, v656, v657, v658) = trace_state () |> option.lazy_unwrap(fn () { v0(v652) })
#     │                                         ^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v658`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:648:18
#     │
# 648 │     let #(v1274, v1275, v1276, v1277, v1278, v1279) = trace_state () |> option.lazy_unwrap(fn () { v0(v1273) })
#     │                  ^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1275`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:648:25
#     │
# 648 │     let #(v1274, v1275, v1276, v1277, v1278, v1279) = trace_state () |> option.lazy_unwrap(fn () { v0(v1273) })
#     │                         ^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1276`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:648:32
#     │
# 648 │     let #(v1274, v1275, v1276, v1277, v1278, v1279) = trace_state () |> option.lazy_unwrap(fn () { v0(v1273) })
#     │                                ^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1277`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:648:39
#     │
# 648 │     let #(v1274, v1275, v1276, v1277, v1278, v1279) = trace_state () |> option.lazy_unwrap(fn () { v0(v1273) })
#     │                                       ^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1278`.
#
# warning: Unused variable
#     ┌─ c:\home\git\polyglot\target\spiral_Eval\packages\3b3d3c33fe6520975b755a40211de513d79274d89e0a6b406bcc7656344e4b0c\src\main.gleam:648:46
#     │
# 648 │     let #(v1274, v1275, v1276, v1277, v1278, v1279) = trace_state () |> option.lazy_unwrap(fn () { v0(v1273) })
#     │                                              ^^^^^ This variable is never used
#
# Hint: You can ignore it with an underscore: `_v1279`.
#
# ? d #1 test1 /
# ? d #2 test2 /
# { name = __assert_eq; actual = 3; expected = 3 }
# .fsx output:
# 00:00:00 d #1 test1
# 00:00:00 d #2 test2
# { name = __assert_eq; actual = 3; expected = 3 }

# %% [markdown]
# ## main

# %%
inl main () =
    init_trace_state None
    inl trace level text_fn (locals : () -> string) = trace level text_fn locals
    $'let trace x = !trace x' : ()
